# %%
import serial
import re
import time
import pygame
import sys
import math

# %%
class Position:
    def __init__(self):
        self.x = 0
        self.y = 0
        self.z = 0

class Orientation:
    def __init__(self):
        self.roll = 0
        self.pitch = 0

class Pose:
    def __init__(self):
        self.position = Position()
        self.orientation = Orientation()

    def update_pose(self, pose_array):
        self.position.x = pose_array[0]
        self.position.y = pose_array[1]
        self.position.z = pose_array[2]
        self.orientation.pitch = pose_array[3]
        self.orientation.roll = pose_array[4]

    def __str__(self):
        return f"X: {self.position.x}, Y: {self.position.y}, Z: {self.position.z}, P: {self.orientation.pitch}, R: {self.orientation.roll}"

# %%
import serial
import re
import time

from Pose import Pose

class Robot:
    def __init__(self, port):
        self.ser = serial.Serial(port)
        self.ser.write(b"CON \r")
        time.sleep(5)
        # self.ser.write(b"HOME \r")
        # time.sleep(160)
        response = self.ser.read_all()
        print(response.decode('ascii'))

        self.pose = Pose()  

        self.get_intial_position()

    def close(self):
        self.ser.close()

    def get_intial_position(self):
        self.ser.write(b"HERE P1 \r")
        time.sleep(1)
        self.ser.write(b"LISTPV P1 \r")
        time.sleep(1)
        response = self.ser.read_all()
        print(response)
        pattern = "X:([\s-]\d+)\s*Y:([\s-]\d+)\s*Z:([\s-]\d+)\s*P:([\s-]\d+)\s*R:([\s-]\d+)"
        # X: 3423, Y: -353, Z: 3423, P: -201, R: 76
        match = re.search(pattern, response.decode('ascii'))
        self.pose.update_pose([
            int(match.group(1)),
            int(match.group(2)),
            int(match.group(3)),
            int(match.group(4)),
            int(match.group(5))
        ])

    
    '''
    Starts from the initial position and updates the position
    '''

    def move_robot(self, increment, delay, delay2):
        if not (5000 < self.pose.position.z < 7000):
            print("not a valid movement")
            pass
        self.pose.update_pose([
            self.pose.position.x,
            self.pose.position.y,
            self.pose.position.z + increment,
            self.pose.orientation.pitch,
            self.pose.orientation.roll,
        ])
        
        print(self.ser.read_all())
        position_command = f"SETPVC P1 Z {self.pose.position.z} \r"
        self.ser.write(bytes(position_command, encoding='utf-8'))
        check = ''
        while True:
            check += self.ser.read_all().decode('ascii')
            print(check)
            if bool(re.search("Done.", check)):
                break
            time.sleep(delay)
        position_command = f"MOVEL P1 {delay2}\r"
        self.ser.write(bytes(position_command, encoding='utf-8'))
        check = ''
        while True:
            check += self.ser.read_all().decode('ascii')
            print(check)
            if bool(re.search("Done.", check)):
                break
            time.sleep(delay)

    def print_pose(self):
        print(self.pose)

# %%
robot = Robot("COM5")
# Out:
# CON
# CONTROL ENABLED.
# >
# b'HERE P1 \r\n\x00Done.\r\n>LISTPV P1 \r\nPosition P1\r\n 1: 1       2:-515     3:-823     4: 232     5: 392    \r\n X: 7469    Y:-352     Z: 6522    P: 73      R:-165    \r\n>'

# %%
pygame.init()
pygame.joystick.init()

joystick = pygame.joystick.Joystick(0)
joystick.init()

running = True

r1_pressed = False
l1_pressed = False

while running:
    start_time = time.time()
    if (r1_pressed):
        robot.move_robot_z(20, 0.1, 50)
    
    if (l1_pressed):
        robot.move_robot_z(-20, 0.1, 50)
        
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            running = False
            robot.close()
            pygame.quit()

        if event.type == pygame.JOYBUTTONDOWN:
            # print(event)
            if event.button == 4:
                l1_pressed = True
            if event.button == 5:
                r1_pressed = True
        if event.type == pygame.JOYBUTTONUP:
            # print(event)
            if event.button == 4:
                l1_pressed = False
            if event.button == 5:
                r1_pressed = False
    time.sleep(0.05)
    # end_time = time.time()
    # if (r1_pressed) or (l1_pressed):
    #     print(end_time - start_time)
# Out:
# b'\r\n\x00Done.\r\n>'
#
# SETPVC P1 Z 6572
# SETPVC P1 Z 6572
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# b''
#
# SETPVC P1 Z 6592
# SETPVC P1 Z 6592
# SETPVC P1 Z 6592
# SETPVC P1 Z 6592
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
#
# b'>'
#
# SETPVC P1 Z 6612
# SETPVC P1 Z 6612
# SETPVC P1 Z 6612
# SETPVC P1 Z 6612
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# b''
#
# SETPVC P1 Z 6632
# SETPVC P1 Z 6632
# SETPVC P1 Z 6632
# SETPVC P1 Z 6632
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\n>'
#
# SETPVC P1 Z 6652
# SETPVC P1 Z 6652
# SETPVC P1 Z 6652
# SETPVC P1 Z 6652
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\r\n>'
#
# SETPVC P1 Z 6672
# SETPVC P1 Z 6672
# SETPVC P1 Z 6672
# SETPVC P1 Z 6672
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\r\n>'
#
# SETPVC P1 Z 6692
# SETPVC P1 Z 6692
# SETPVC P1 Z 6692
# SETPVC P1 Z 6692
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\r\n>'
#
# SETPVC P1 Z 6712
# SETPVC P1 Z 6712
# SETPVC P1 Z 6712
# SETPVC P1 Z 6712
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\n>'
#
# SETPVC P1 Z 6732
# SETPVC P1 Z 6732
# SETPVC P1 Z 6732
# SETPVC P1 Z 6732
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\r\n>'
#
# SETPVC P1 Z 6752
# SETPVC P1 Z 6752
# SETPVC P1 Z 6752
# SETPVC P1 Z 6752
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\n>'
#
# SETPVC P1 Z 6772
# SETPVC P1 Z 6772
# SETPVC P1 Z 6772
# SETPVC P1 Z 6772
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# b''
#
# SETPVC P1 Z 6792
# SETPVC P1 Z 6792
# SETPVC P1 Z 6792
# SETPVC P1 Z 6792
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\n>'
#
# SETPVC P1 Z 6812
# SETPVC P1 Z 6812
# SETPVC P1 Z 6812
# SETPVC P1 Z 6812
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\n>'
#
# SETPVC P1 Z 6832
# SETPVC P1 Z 6832
# SETPVC P1 Z 6832
# SETPVC P1 Z 6832
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# b''
#
# SETPVC P1 Z 6852
# SETPVC P1 Z 6852
# SETPVC P1 Z 6852
# SETPVC P1 Z 6852
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# >
# b''
#
# SETPVC P1 Z 6872
# SETPVC P1 Z 6872
# SETPVC P1 Z 6872
# SETPVC P1 Z 6872
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# b''
#
# SETPVC P1 Z 6892
# SETPVC P1 Z 6892
# SETPVC P1 Z 6892
# SETPVC P1 Z 6892
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# b''
#
# SETPVC P1 Z 6912
# SETPVC P1 Z 6912
# SETPVC P1 Z 6912
# SETPVC P1 Z 6912
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
#
# b'>'
#
# SETPVC P1 Z 6932
# SETPVC P1 Z 6932
# SETPVC P1 Z 6932
# SETPVC P1 Z 6932
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\r\n>'
#
# SETPVC P1 Z 6952
# SETPVC P1 Z 6952
# SETPVC P1 Z 6952
# SETPVC P1 Z 6952
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\r\n>'
#
# SETPVC P1 Z 6972
# SETPVC P1 Z 6972
# SETPVC P1 Z 6972
# SETPVC P1 Z 6972
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# b'\n>'
#
# SETPVC P1 Z 6992
# SETPVC P1 Z 6992
# SETPVC P1 Z 6992
# SETPVC P1 Z 6992
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# b''
#
# SETPVC P1 Z 7012
# SETPVC P1 Z 7012
# SETPVC P1 Z 7012
# SETPVC P1 Z 7012
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7032
# SETPVC P1 Z 7032
# SETPVC P1 Z 7032
# SETPVC P1 Z 7032
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7012
# SETPVC P1 Z 7012
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 6992
# SETPVC P1 Z 6992
# SETPVC P1 Z 6992
# SETPVC P1 Z 6992
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# >
# b''
#
# SETPVC P1 Z 7012
# SETPVC P1 Z 7012
# SETPVC P1 Z 7012
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7032
# SETPVC P1 Z 7032
# SETPVC P1 Z 7032
# SETPVC P1 Z 7032
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7052
# SETPVC P1 Z 7052
# SETPVC P1 Z 7052
# SETPVC P1 Z 7052
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7072
# SETPVC P1 Z 7072
# SETPVC P1 Z 7072
# SETPVC P1 Z 7072
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7092
# SETPVC P1 Z 7092
# SETPVC P1 Z 7092
# SETPVC P1 Z 7092
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7112
# SETPVC P1 Z 7112
# SETPVC P1 Z 7112
# SETPVC P1 Z 7112
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
#
# not a valid movement
# b'>'
#
# SETPVC P1 Z 7132
# SETPVC P1 Z 7132
# SETPVC P1 Z 7132
# SETPVC P1 Z 7132
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7152
# SETPVC P1 Z 7152
# SETPVC P1 Z 7152
# SETPVC P1 Z 7152
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
#
# not a valid movement
# b'>'
#
# SETPVC P1 Z 7192
# SETPVC P1 Z 7192
# SETPVC P1 Z 7192
# SETPVC P1 Z 7192
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7212
# SETPVC P1 Z 7212
# SETPVC P1 Z 7212
# SETPVC P1 Z 7212
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7232
# SETPVC P1 Z 7232
# SETPVC P1 Z 7232
# SETPVC P1 Z 7232
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7252
# SETPVC P1 Z 7252
# SETPVC P1 Z 7252
# SETPVC P1 Z 7252
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7272
# SETPVC P1 Z 7272
# SETPVC P1 Z 7272
# SETPVC P1 Z 7272
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7292
# SETPVC P1 Z 7292
# SETPVC P1 Z 7292
# SETPVC P1 Z 7292
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7312
# SETPVC P1 Z 7312
# SETPVC P1 Z 7312
# SETPVC P1 Z 7312
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7412
# SETPVC P1 Z 7412
# SETPVC P1 Z 7412
# SETPVC P1 Z 7412
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
#
# not a valid movement
# b'>'
#
# SETPVC P1 Z 7312
# SETPVC P1 Z 7312
# SETPVC P1 Z 7312
# SETPVC P1 Z 7312
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7292
# SETPVC P1 Z 7292
# SETPVC P1 Z 7292
# SETPVC P1 Z 7292
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7272
# SETPVC P1 Z 7272
# SETPVC P1 Z 7272
# SETPVC P1 Z 7272
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7252
# SETPVC P1 Z 7252
# SETPVC P1 Z 7252
# SETPVC P1 Z 7252
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7232
# SETPVC P1 Z 7232
# SETPVC P1 Z 7232
# SETPVC P1 Z 7232
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7212
# SETPVC P1 Z 7212
# SETPVC P1 Z 7212
# SETPVC P1 Z 7212
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
#
# not a valid movement
# b'>'
#
# SETPVC P1 Z 7192
# SETPVC P1 Z 7192
# SETPVC P1 Z 7192
# SETPVC P1 Z 7192
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7152
# SETPVC P1 Z 7152
# SETPVC P1 Z 7152
# SETPVC P1 Z 7152
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7152
# SETPVC P1 Z 7152
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7132
# SETPVC P1 Z 7132
# SETPVC P1 Z 7132
# SETPVC P1 Z 7132
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7152
# SETPVC P1 Z 7152
# Done
# SETPVC P1 Z 7152
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# SETPVC P1 Z 7172
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7192
# SETPVC P1 Z 7192
# SETPVC P1 Z 7192
# SETPVC P1 Z 7192
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7212
# SETPVC P1 Z 7212
# SETPVC P1 Z 7212
# SETPVC P1 Z 7212
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Don
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7232
# SETPVC P1 Z 7232
# SETPVC P1 Z 7232
# SETPVC P1 Z 7232
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7252
# SETPVC P1 Z 7252
# SETPVC P1 Z 7252
# SETPVC P1 Z 7252
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7272
# SETPVC P1 Z 7272
# SETPVC P1 Z 7272
# SETPVC P1 Z 7272
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7292
# SETPVC P1 Z 7292
# SETPVC P1 Z 7292
# Do
# SETPVC P1 Z 7292
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7312
# SETPVC P1 Z 7312
# SETPVC P1 Z 7312
# SETPVC P1 Z 7312
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
#
# not a valid movement
# b'>'
#
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
#
# not a valid movement
# b'>'
#
# SETPVC P1 Z 7412
# SETPVC P1 Z 7412
# SETPVC P1 Z 7412
# SETPVC P1 Z 7412
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
#
# not a valid movement
# b'>'
#
# SETPVC P1 Z 7432
# SETPVC P1 Z 7432
# SETPVC P1 Z 7432
# SETPVC P1 Z 7432
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7452
# SETPVC P1 Z 7452
# SETPVC P1 Z 7452
# SETPVC P1 Z 7452
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7472
# SETPVC P1 Z 7472
# SETPVC P1 Z 7472
# SETPVC P1 Z 7472
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7492
# SETPVC P1 Z 7492
# SETPVC P1 Z 7492
# SETPVC P1 Z 7492
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7472
# SETPVC P1 Z 7472
# SETPVC P1 Z 7472
# SETPVC P1 Z 7472
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7452
# SETPVC P1 Z 7452
# SETPVC P1 Z 7452
# SETPVC P1 Z 7452
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7432
# SETPVC P1 Z 7432
# SETPVC P1 Z 7432
# SETPVC P1 Z 7432
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7412
# SETPVC P1 Z 7412
# SETPVC P1 Z 7412
# Do
# SETPVC P1 Z 7412
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# >
# not a valid movement
# b''
#
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# SETPVC P1 Z 7392
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# SETPVC P1 Z 7372
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\n>'
#
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# SETPVC P1 Z 7352
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# not a valid movement
# b'\r\n>'
#
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# SETPVC P1 Z 7332
# Done.
# >
#
# MOVEL P1 50
# MOVEL P1 50
# Done.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\fatim\Desktop\IST\Robotics\scorbot\all.ipynb Cell 5 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W5sZmlsZQ%3D%3D?line=35'>36</a>         if event.button == 5:
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W5sZmlsZQ%3D%3D?line=36'>37</a>             r1_pressed = False
# ---> <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W5sZmlsZQ%3D%3D?line=37'>38</a> time.sleep(0.05)
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W5sZmlsZQ%3D%3D?line=38'>39</a> # end_time = time.time()
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W5sZmlsZQ%3D%3D?line=39'>40</a> # if (r1_pressed) or (l1_pressed):
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W5sZmlsZQ%3D%3D?line=40'>41</a> #     print(end_time - start_time)
#
# KeyboardInterrupt:

# %%
robot.close()

# %%
robot.move_robot_z(-100, 0.05, 0.0)
# Out:
# ---------------------------------------------------------------------------
# SerialException                           Traceback (most recent call last)
# c:\Users\fatim\Desktop\IST\Robotics\scorbot\all.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=0'>1</a> robot.move_robot_z(-100, 0.05, 0.0)
#
# c:\Users\fatim\Desktop\IST\Robotics\scorbot\all.ipynb Cell 5 line 5
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=49'>50</a>     pass
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=50'>51</a> self.pose.update_pose([
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=51'>52</a>     self.pose.position.x,
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=52'>53</a>     self.pose.position.y,
#    (...)
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=55'>56</a>     self.pose.orientation.roll,
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=56'>57</a> ])
# ---> <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=58'>59</a> print(self.ser.read_all())
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=59'>60</a> position_command = f"SETPVC P1 Z {self.pose.position.z} \r"
#      <a href='vscode-notebook-cell:/c%3A/Users/fatim/Desktop/IST/Robotics/scorbot/all.ipynb#W4sZmlsZQ%3D%3D?line=60'>61</a> self.ser.write(bytes(position_command, encoding='utf-8'))
#
# File c:\Users\fatim\miniconda3\lib\site-packages\serial\serialutil.py:652, in SerialBase.read_all(self)
#     648 def read_all(self):
#     649     """\
#     650     Read all bytes currently available in the buffer of the OS.
#     651     """
# --> 652     return self.read(self.in_waiting)
#
# File c:\Users\fatim\miniconda3\lib\site-packages\serial\serialwin32.py:259, in Serial.in_waiting(self)
#     257 comstat = win32.COMSTAT()
#     258 if not win32.ClearCommError(self._port_handle, ctypes.byref(flags), ctypes.byref(comstat)):
# --> 259     raise SerialException("ClearCommError failed ({!r})".format(ctypes.WinError()))
#     260 return comstat.cbInQue
#
# SerialException: ClearCommError failed (PermissionError(13, 'The device does not recognize the command.', None, 22))
